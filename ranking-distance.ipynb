# %% [markdown]
# # Distance Metrics for Ranking Lists

# %%
import numpy as np

# %% [markdown]
# ## Standard Distance

# %%
def kendall_tau(a: np.array, b: np.array) -> int:
    dist = 0
    for i in range(a.shape[0]):
        for j in range(i + 1, a.shape[0]):
            dist += (a[i] > a[j]) != (b[i] > b[j])
    return dist

# %%
arr_a = np.array([1, 2, 3, 4, 5])
arr_b = np.array([2, 1, 4, 5, 3])

kendall_tau(arr_a, arr_b)
# Out:
# np.int64(3)

# %%
arr_a = np.array([1, 2, 3, 4, 5])
arr_b = np.array([2, 5, 4, 1, 3])

kendall_tau(arr_a, arr_b)
# Out:
# np.int64(6)

# %%
arr_a = np.array([1, 2, 3, 4, 5])
arr_b = np.array([5, 1, 4, 2, 3])

kendall_tau(arr_a, arr_b)
# Out:
# np.int64(6)

# %% [markdown]
# ## Weighted Distance

# %%
def kendall_tau_weighted(a: np.array, b: np.array, w: np.array) -> int:
    dist = 0
    for i in range(a.shape[0]):
        for j in range(i + 1, a.shape[0]):
            dist += w[i] * w[j] * ((a[i] > a[j]) != (b[i] > b[j]))
    return dist

# %%
arr_a = np.array([1, 2, 3, 4, 5])
arr_b = np.array([2, 1, 4, 5, 3])
weights = np.array([1.0, 0.8, 0.6, 0.4, 0.2])

kendall_tau_weighted(arr_a, arr_b, weights)
# Out:
# np.float64(1.0)

# %%
arr_a = np.array([1, 2, 3, 4, 5])
arr_b = np.array([2, 5, 4, 1, 3])
weights = np.array([1.0, 0.8, 0.6, 0.4, 0.2])

kendall_tau_weighted(arr_a, arr_b, weights)
# Out:
# np.float64(1.7200000000000002)

# %%
arr_a = np.array([1, 2, 3, 4, 5])
arr_b = np.array([5, 1, 4, 2, 3])
weights = np.array([1.0, 0.8, 0.6, 0.4, 0.2])

kendall_tau_weighted(arr_a, arr_b, weights)
# Out:
# np.float64(2.36)

# %% [markdown]
# ## Top-Item Recovery

# %%
def kendall_tau_top(a: np.array, b: np.array, w: np.array) -> int:
    dist = 0
    for j in range(1, a.shape[0]):
        dist += w[j] * ((a[0] > a[j]) != (b[0] > b[j]))
    return dist

# %%
arr_a = np.array([1, 2, 3, 4, 5])
arr_b = np.array([2, 1, 4, 5, 3])
weights = np.array([1.0, 0.8, 0.6, 0.4, 0.2])

kendall_tau_top(arr_a, arr_b, weights)
# Out:
# np.float64(0.8)

# %%
arr_a = np.array([1, 2, 3, 4, 5])
arr_b = np.array([2, 5, 4, 1, 3])
weights = np.array([1.0, 0.8, 0.6, 0.4, 0.2])

kendall_tau_top(arr_a, arr_b, weights)
# Out:
# np.float64(0.4)

# %%
arr_a = np.array([1, 2, 3, 4, 5])
arr_b = np.array([5, 1, 4, 2, 3])
weights = np.array([1.0, 0.8, 0.6, 0.4, 0.2])

kendall_tau_top(arr_a, arr_b, weights)
# Out:
# np.float64(1.9999999999999998)
