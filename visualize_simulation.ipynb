# %%
import polars as pl
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pl.read_parquet("./data/diversity_utilities")
df
# Out:
# shape: (11_127_152, 9)
# ┌────────────┬───────────┬──────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Human-Rank ┆ Algo-Rank ┆ Utility  ┆ Distance ┆ … ┆ Human-Bet ┆ Algorithm ┆ Algorithm ┆ Algorithm │
# │ ing        ┆ ing       ┆ ---      ┆ ---      ┆   ┆ a         ┆ -Beta     ┆ -Alpha    ┆ -Sigma    │
# │ ---        ┆ ---       ┆ f64      ┆ i64      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ list[i64]  ┆ list[i64] ┆          ┆          ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪═══════════╪══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ [5, 8, …   ┆ [5, 8, …  ┆ 0.794925 ┆ 0        ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.85      ┆ 1.5       │
# │ 10]        ┆ 10]       ┆          ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 3, …   ┆ [8, 3, …  ┆ 0.793643 ┆ 0        ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.85      ┆ 1.5       │
# │ 10]        ┆ 10]       ┆          ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 3, …   ┆ [8, 3, …  ┆ 0.793629 ┆ 0        ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.85      ┆ 1.5       │
# │ 7]         ┆ 7]        ┆          ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 3, …   ┆ [8, 3, …  ┆ 0.793629 ┆ 0        ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.85      ┆ 1.5       │
# │ 7]         ┆ 7]        ┆          ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [2, 8, …   ┆ [2, 8, …  ┆ 0.793647 ┆ 0        ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.85      ┆ 1.5       │
# │ 10]        ┆ 10]       ┆          ┆          ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …         ┆ …        ┆ …        ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ [8, 3, …   ┆ [8, 6, …  ┆ 0.826157 ┆ 9        ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 10]        ┆ 2]        ┆          ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 3, …   ┆ [8, 6, …  ┆ 0.826157 ┆ 9        ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 10]        ┆ 10]       ┆          ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 3, …   ┆ [8, 3, …  ┆ 0.799351 ┆ 9        ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 10]        ┆ 10]       ┆          ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 3, …   ┆ [8, 6, …  ┆ 0.826157 ┆ 9        ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 10]        ┆ 10]       ┆          ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 3, …   ┆ [8, 5, …  ┆ 0.837552 ┆ 9        ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 10]        ┆ 10]       ┆          ┆          ┆   ┆           ┆           ┆           ┆           │
# └────────────┴───────────┴──────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df.filter(
    pl.col("Utility") == pl.col("Utility").max()
)
# Out:
# shape: (274, 9)
# ┌────────────┬────────────┬─────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Human-Rank ┆ Algo-Ranki ┆ Utility ┆ Distance ┆ … ┆ Human-Bet ┆ Algorithm ┆ Algorithm ┆ Algorithm │
# │ ing        ┆ ng         ┆ ---     ┆ ---      ┆   ┆ a         ┆ -Beta     ┆ -Alpha    ┆ -Sigma    │
# │ ---        ┆ ---        ┆ f64     ┆ i64      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ list[i64]  ┆ list[i64]  ┆         ┆          ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ [8, 3, …   ┆ [8, 10, …  ┆ 0.84327 ┆ 18       ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 10]        ┆ 1]         ┆         ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 1, …   ┆ [8, 10, …  ┆ 0.84327 ┆ 18       ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 10]        ┆ 5]         ┆         ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [3, 8, …   ┆ [3, 10, …  ┆ 0.84327 ┆ 18       ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 10]        ┆ 5]         ┆         ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 6, …   ┆ [8, 7, …   ┆ 0.84327 ┆ 18       ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 7]         ┆ 10]        ┆         ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [2, 1, …   ┆ [2, 8, …   ┆ 0.84327 ┆ 18       ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 8]         ┆ 5]         ┆         ┆          ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …       ┆ …        ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ [6, 5, …   ┆ [6, 9, …   ┆ 0.84327 ┆ 27       ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 9]         ┆ 5]         ┆         ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 5, …   ┆ [8, 7, …   ┆ 0.84327 ┆ 27       ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 7]         ┆ 5]         ┆         ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [6, 5, …   ┆ [6, 9, …   ┆ 0.84327 ┆ 27       ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 9]         ┆ 2]         ┆         ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 5, …   ┆ [8, 7, …   ┆ 0.84327 ┆ 27       ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 7]         ┆ 6]         ┆         ┆          ┆   ┆           ┆           ┆           ┆           │
# │ [8, 6, …   ┆ [8, 7, …   ┆ 0.84327 ┆ 27       ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.0       ┆ 1.5       │
# │ 7]         ┆ 5]         ┆         ┆          ┆   ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴─────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df.filter(
    pl.col("Utility") == pl.col("Utility").min()
)
# Out:
# shape: (1, 9)
# ┌────────────┬────────────┬─────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Human-Rank ┆ Algo-Ranki ┆ Utility ┆ Distance ┆ … ┆ Human-Bet ┆ Algorithm ┆ Algorithm ┆ Algorithm │
# │ ing        ┆ ng         ┆ ---     ┆ ---      ┆   ┆ a         ┆ -Beta     ┆ -Alpha    ┆ -Sigma    │
# │ ---        ┆ ---        ┆ f64     ┆ i64      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ list[i64]  ┆ list[i64]  ┆         ┆          ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ [5, 8, …   ┆ [9, 6, …   ┆ 0.01962 ┆ 27       ┆ … ┆ 1.5       ┆ 1.5       ┆ 0.85      ┆ 1.5       │
# │ 9]         ┆ 5]         ┆         ┆          ┆   ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴─────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df["Utility"].max()
# Out:
# 0.8432704200782205

# %%
distance_counts = df["Distance"].value_counts()

with pl.Config(tbl_rows=-1):
    print(distance_counts)
# Out:
# shape: (6, 2)
# ┌──────────┬─────────┐
# │ Distance ┆ count   │
# │ ---      ┆ ---     │
# │ i64      ┆ u32     │
# ╞══════════╪═════════╡
# │ 27       ┆ 2854704 │
# │ 36       ┆ 201888  │
# │ 45       ┆ 32      │
# │ 18       ┆ 6214392 │
# │ 9        ┆ 1855496 │
# │ 0        ┆ 640     │
# └──────────┴─────────┘

# %%
temp_df = df.filter(
    pl.col("Uses-Human-Utility") == False,
    #pl.col("Distance").is_in([0, 9]),
    #pl.col("Algorithm-Alpha") == 0.85
).with_columns(
    ("Hβ: " + pl.concat_str([
        pl.col("Human-Beta"),
        pl.col("Algorithm-Alpha")
    ], separator=" x Aα: ")).alias("section"),
    ("Distance " + pl.col("Distance").cast(pl.String)).alias("Distance")
)

temp_df
# Out:
# shape: (5_563_576, 10)
# ┌───────────┬───────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Human-Ran ┆ Algo-Rank ┆ Utility  ┆ Distance  ┆ … ┆ Algorithm ┆ Algorithm ┆ Algorithm ┆ section   │
# │ king      ┆ ing       ┆ ---      ┆ ---       ┆   ┆ -Beta     ┆ -Alpha    ┆ -Sigma    ┆ ---       │
# │ ---       ┆ ---       ┆ f64      ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ str       │
# │ list[i64] ┆ list[i64] ┆          ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆           │
# ╞═══════════╪═══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ [5, 8, …  ┆ [5, 8, …  ┆ 0.794925 ┆ Distance  ┆ … ┆ 1.5       ┆ 0.85      ┆ 1.5       ┆ Hβ: 1.5 x │
# │ 10]       ┆ 10]       ┆          ┆ 0         ┆   ┆           ┆           ┆           ┆ Aα: 0.85  │
# │ [8, 3, …  ┆ [8, 3, …  ┆ 0.793643 ┆ Distance  ┆ … ┆ 1.5       ┆ 0.85      ┆ 1.5       ┆ Hβ: 1.5 x │
# │ 10]       ┆ 10]       ┆          ┆ 0         ┆   ┆           ┆           ┆           ┆ Aα: 0.85  │
# │ [8, 3, …  ┆ [8, 3, …  ┆ 0.793629 ┆ Distance  ┆ … ┆ 1.5       ┆ 0.85      ┆ 1.5       ┆ Hβ: 1.5 x │
# │ 7]        ┆ 7]        ┆          ┆ 0         ┆   ┆           ┆           ┆           ┆ Aα: 0.85  │
# │ [8, 3, …  ┆ [8, 3, …  ┆ 0.793629 ┆ Distance  ┆ … ┆ 1.5       ┆ 0.85      ┆ 1.5       ┆ Hβ: 1.5 x │
# │ 7]        ┆ 7]        ┆          ┆ 0         ┆   ┆           ┆           ┆           ┆ Aα: 0.85  │
# │ [2, 8, …  ┆ [2, 8, …  ┆ 0.793647 ┆ Distance  ┆ … ┆ 1.5       ┆ 0.85      ┆ 1.5       ┆ Hβ: 1.5 x │
# │ 10]       ┆ 10]       ┆          ┆ 0         ┆   ┆           ┆           ┆           ┆ Aα: 0.85  │
# │ …         ┆ …         ┆ …        ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ [8, 3, …  ┆ [8, 3, …  ┆ 0.670329 ┆ Distance  ┆ … ┆ 1.5       ┆ 0.0       ┆ 1.5       ┆ Hβ: 0.5 x │
# │ 1]        ┆ 10]       ┆          ┆ 9         ┆   ┆           ┆           ┆           ┆ Aα: 0.0   │
# │ [8, 1, …  ┆ [8, 6, …  ┆ 0.738015 ┆ Distance  ┆ … ┆ 1.5       ┆ 0.0       ┆ 1.5       ┆ Hβ: 0.5 x │
# │ 7]        ┆ 4]        ┆          ┆ 9         ┆   ┆           ┆           ┆           ┆ Aα: 0.0   │
# │ [1, 4, …  ┆ [1, 4, …  ┆ 0.670329 ┆ Distance  ┆ … ┆ 1.5       ┆ 0.0       ┆ 1.5       ┆ Hβ: 0.5 x │
# │ 6]        ┆ 5]        ┆          ┆ 9         ┆   ┆           ┆           ┆           ┆ Aα: 0.0   │
# │ [8, 5, …  ┆ [8, 6, …  ┆ 0.738015 ┆ Distance  ┆ … ┆ 1.5       ┆ 0.0       ┆ 1.5       ┆ Hβ: 0.5 x │
# │ 3]        ┆ 7]        ┆          ┆ 9         ┆   ┆           ┆           ┆           ┆ Aα: 0.0   │
# │ [2, 8, …  ┆ [8, 2, …  ┆ 0.570617 ┆ Distance  ┆ … ┆ 1.5       ┆ 0.0       ┆ 1.5       ┆ Hβ: 0.5 x │
# │ 5]        ┆ 5]        ┆          ┆ 9         ┆   ┆           ┆           ┆           ┆ Aα: 0.0   │
# └───────────┴───────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
temp_df["section"].value_counts()
# Out:
# shape: (4, 2)
# ┌────────────────────┬─────────┐
# │ section            ┆ count   │
# │ ---                ┆ ---     │
# │ str                ┆ u32     │
# ╞════════════════════╪═════════╡
# │ Hβ: 1.5 x Aα: 0.0  ┆ 1390894 │
# │ Hβ: 0.5 x Aα: 0.85 ┆ 1390894 │
# │ Hβ: 0.5 x Aα: 0.0  ┆ 1390894 │
# │ Hβ: 1.5 x Aα: 0.85 ┆ 1390894 │
# └────────────────────┴─────────┘

# %%
g = sns.FacetGrid(
    temp_df, row="Distance", aspect=6, height=2.4,
    row_order=[f"Distance {d}" for d in range(0, 46, 9)],
    #sharex=False, 
    sharey=False,
    hue="section", 
    hue_order=["Hβ: 1.5 x Aα: 0.85", "Hβ: 0.5 x Aα: 0.85", "Hβ: 1.5 x Aα: 0.0", "Hβ: 0.5 x Aα: 0.0"],
    palette=['mediumseagreen', 'skyblue', 'darkgreen', 'darkblue']
)

g.map_dataframe(
    sns.kdeplot, "Utility", fill=True, clip_on=False
)

def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, x.iloc[0], fontweight="bold", color='black',
            ha="left", va="center", transform=ax.transAxes)

g.map(label, "Distance")

for ax in g.axes.flat:
    ax.axhline(y=0, lw=2, clip_on=False, color="black")
    ax.set_facecolor("none")

g.figure.subplots_adjust(hspace=-.15)

g.set_titles("")
g.figure.suptitle("Utilities for Sufficient Algorithm Views")
g.set(yticks=[], xlabel="")
g.set_xlabels("Utility")
g.despine(bottom=True, left=True)

g.add_legend(title="Sections")

plt.show()

# %%
sns.displot(
    temp_df, x="Utility", hue="section", 
    #binwidth=0.005
)

#plt.xlim(0, 1)
plt.show()

# %%
sns.displot(
    temp_df, x="Utility", hue="section", element="step", 
    #binwidth=0.005
)

#plt.xlim(0, 1)
plt.show()

# %%
sns.displot(
    temp_df, x="Utility", hue="section", kind="kde", multiple="stack", 
    #bw_adjust=.05
)
plt.show()

# %%
sns.kdeplot(
    temp_df, x="Utility", hue="section", fill=True, 
    #bw_adjust=.05
)
plt.show()

# %%
sns.displot(
    temp_df, x="Utility", hue="section", kind="kde", fill=True, 
    #bw_adjust=.05
)
plt.show()

# %%
sns.displot(temp_df, x="Utility", hue="section", kind="ecdf")
plt.show()
